# %%
import os
import json
import sys
sys_path = 'D:/Research_CAE/MyTinyCUDANN/tiny-cuda-nn/main'
sys.path.append(sys_path)
from tools import my_mkdir

# %% [markdown]
# One task (Test)

# %%
task_folder = os.path.dirname(os.path.abspath("__file__"))
task_folder = os.path.join(task_folder, 'Tasks', 'foo')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"optimizer": {
		"type": "Adam",
		"learning_rate": 1e-2,
		"beta1": 0.9,
		"beta2": 0.99,
		"epsilon": 1e-15,
		"l2_reg": 1e-6
	},
	"encoding": {
		"type": "Grid",
		"type": "Hash",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.5
	},
	"network": {
		"type": "MLP",
		"activation": "ReLU",
		"output_activation": "None",
		"n_neurons": 64,
		"n_hidden_layers": 2
	}
}
file_path = os.path.join(task_folder, 'config.json')
with open(file_path, 'w') as f:
  json.dump(task_hyperparameter, f, ensure_ascii=False)
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Poisson_DirichletBC\Tasks\foo

# %% [markdown]
# PINN_lambda

# %%
task_folder = os.path.dirname(os.path.abspath("__file__"))
task_folder = os.path.join(task_folder, 'Tasks', 'PINN_lambda')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 64,
		"n_hidden_layers": 5
	},
    "loss": {
        "type": "strong",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "LBFGS",
		"learning_rate": 1e-1,
		"max_iter": 600,
		"n_step_decay":2000,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"experiment":{
		"n_test": 10,
	}
}
lambda_list = [0.01,0.1,1,10,100,1000,5000,10000]
i = 0
for lam in lambda_list:
	task_hyperparameter['loss']['lambda'] = lam
	file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
	with open(file_path, 'w') as f:
		json.dump(task_hyperparameter, f, ensure_ascii=False)
	i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Poisson_DirichletBC\Tasks\PINN_lambda

# %% [markdown]
# PINN_lambda (ADAM)

# %%
task_folder = os.path.dirname(os.path.abspath("__file__"))
task_folder = os.path.join(task_folder, 'Tasks', 'PINN_lambda_ADAM')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 64,
		"n_hidden_layers": 5
	},
    "loss": {
        "type": "strong",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":800,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"experiment":{
		"n_test": 10,
	}
}
lambda_list = [0.01,0.1,1,10,100,1000,5000,10000]
i = 0
for lam in lambda_list:
	task_hyperparameter['loss']['lambda'] = lam
	file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
	with open(file_path, 'w') as f:
		json.dump(task_hyperparameter, f, ensure_ascii=False)
	i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Poisson_DirichletBC\Tasks\PINN_lambda_ADAM

# %%
task_folder = os.path.dirname(os.path.abspath("__file__"))
task_folder = os.path.join(task_folder, 'Tasks', 'PINN_energy_lambda_ADAM')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 64,
		"n_hidden_layers": 5
	},
    "loss": {
        "type": "strong",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":800,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"experiment":{
		"n_test": 10,
	}
}
lambda_list = [100,1000,5000,10000,10,1,50000]
i = 0
for lam in lambda_list:
	task_hyperparameter['loss']['lambda'] = lam
	file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
	with open(file_path, 'w') as f:
		json.dump(task_hyperparameter, f, ensure_ascii=False)
	i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Poisson_DirichletBC\Tasks\PINN_energy_lambda_ADAM

# %%
task_folder = os.path.dirname(os.path.abspath("__file__"))
task_folder = os.path.join(task_folder, 'Tasks', 'GridMLP_decoupled')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 20,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}

i = 1


file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
with open(file_path, 'w') as f:
	json.dump(task_hyperparameter, f, ensure_ascii=False)
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Poisson_DirichletBC\Tasks\GridMLP_decoupled

# %%
task_folder = os.path.dirname(os.path.abspath("__file__"))
task_folder = os.path.join(task_folder, 'Tasks', 'GridMLP_standard')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}


lambda_list = [0.1,1,10,100,1000,5000,10000,50000,100000,500000,1000000]
i = 0
for lam in lambda_list:
	task_hyperparameter['loss']['lambda'] = lam
	file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
	with open(file_path, 'w') as f:
		json.dump(task_hyperparameter, f, ensure_ascii=False)
	i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Poisson_DirichletBC\Tasks\GridMLP_standard
