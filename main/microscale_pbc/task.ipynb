# %%
import os
import json
import sys
import numpy as np
sys_path = 'D:/Research_CAE/MyTinyCUDANN/tiny-cuda-nn/main'
sys.path.append(sys_path)
from tools import my_mkdir
main_task_folder = os.path.join(os.path.dirname(os.path.abspath("__file__")), 'Tasks')
my_mkdir(main_task_folder)

# %% [markdown]
# One task (Test)

# %%
task_folder = os.path.join(main_task_folder, 'foo')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"optimizer": {
		"type": "Adam",
		"learning_rate": 1e-2,
		"beta1": 0.9,
		"beta2": 0.99,
		"epsilon": 1e-15,
		"l2_reg": 1e-6
	},
	"encoding": {
		"type": "Grid",
		"type": "Hash",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.5
	},
	"network": {
		"type": "MLP",
		"activation": "ReLU",
		"output_activation": "None",
		"n_neurons": 64,
		"n_hidden_layers": 2
	}
}
file_path = os.path.join(task_folder, 'config.json')
with open(file_path, 'w') as f:
  json.dump(task_hyperparameter, f, ensure_ascii=False)
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Poisson_DirichletBC\Tasks\foo

# %% [markdown]
# PINN_lambda

# %%
task_folder = os.path.join(main_task_folder, 'PINN_lambda')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 64,
		"n_hidden_layers": 5
	},
    "loss": {
        "type": "strong",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "LBFGS",
		"learning_rate": 1e-1,
		"max_iter": 600,
		"n_step_decay":2000,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"experiment":{
		"n_test": 10,
	}
}
lambda_list = [0.01,0.1,1,10,100,1000,5000,10000]
i = 0
for lam in lambda_list:
	task_hyperparameter['loss']['lambda'] = lam
	file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
	with open(file_path, 'w') as f:
		json.dump(task_hyperparameter, f, ensure_ascii=False)
	i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Poisson_DirichletBC\Tasks\PINN_lambda

# %% [markdown]
# PINN_lambda (ADAM)

# %%
task_folder = os.path.join(main_task_folder, 'PINN_lambda_ADAM_sin')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Sin",
		"n_neurons": 64,
		"n_hidden_layers": 5
	},
    "loss": {
        "type": "strong",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":800,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"experiment":{
		"n_test": 10,
	}
}
lambda_list = [0.01,0.1,1,10,100,1000,5000,10000]
i = 0
for lam in lambda_list:
	task_hyperparameter['loss']['lambda'] = lam
	file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
	with open(file_path, 'w') as f:
		json.dump(task_hyperparameter, f, ensure_ascii=False)
	i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\Multiscale\Tasks\PINN_lambda_ADAM_sin

# %%
task_folder = os.path.join(main_task_folder, 'PINN_energy_lambda_ADAM_sin')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Sin",
		"n_neurons": 64,
		"n_hidden_layers": 5
	},
    "loss": {
        "type": "strong",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":800,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"experiment":{
		"n_test": 10,
	}
}
lambda_list = [0.1,1,10,100,1000,5000,10000,50000]
i = 0
for lam in lambda_list:
	task_hyperparameter['loss']['lambda'] = lam
	file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
	with open(file_path, 'w') as f:
		json.dump(task_hyperparameter, f, ensure_ascii=False)
	i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\PINN_energy_lambda_ADAM_sin

# %%
task_folder = os.path.join(main_task_folder, 'GridMLP_share')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 20,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}

i = 0


file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
with open(file_path, 'w') as f:
	json.dump(task_hyperparameter, f, ensure_ascii=False)
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\GridMLP_share

# %%
task_folder = os.path.join(main_task_folder, 'GridMLP_standard')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 15,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}


lambda_list = [0.1,1,10,100,1000,5000,10000,50000,100000,500000,1000000]
i = 0
for lam in lambda_list:
	task_hyperparameter['loss']['lambda'] = lam
	file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
	with open(file_path, 'w') as f:
		json.dump(task_hyperparameter, f, ensure_ascii=False)
	i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\GridMLP_standard

# %%
task_folder = os.path.join(main_task_folder, 'GridMLP_share_network_sin_spectral')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 20,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Sin",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}

spectral_norm_list = [0,1]
n_neurons_list = [16,32,64,128]
n_hidden_layers_list = [0,1,2,3]
i = 0
for spectral_norm in spectral_norm_list:
	for n_neurons in n_neurons_list:
		for n_hidden_layers in n_hidden_layers_list:
			task_hyperparameter["network"]['n_neurons'] = n_neurons
			task_hyperparameter["network"]['n_hidden_layers'] = n_hidden_layers
			task_hyperparameter["network"]['spectral_norm'] = spectral_norm
			file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
			with open(file_path, 'w') as f:
				json.dump(task_hyperparameter, f, ensure_ascii=False)
			i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\GridMLP_share_network_sin_spectral

# %%
task_folder = os.path.join(main_task_folder, 'GridMLP_share_levels_network')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 16,
		"n_features_per_level": 2,
		"log2_hashmap_size": 20,
		"base_resolution": 16,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}


n_neurons_list = [16,32]
n_hidden_layers_list = [0,2]
n_levels_list = np.array([4,8,12,16,20],dtype='int')

base_res_0 = task_hyperparameter["encoding"]['base_resolution']
per_level_scale_0 = task_hyperparameter["encoding"]['per_level_scale']
n_levels_0 = task_hyperparameter["encoding"]['n_levels']
max_res = (base_res_0*per_level_scale_0**(n_levels_0-2))
base_resolution_list = np.round((max_res/(per_level_scale_0**(n_levels_list-2)))).astype("int")
print(max_res,(base_resolution_list*per_level_scale_0**(n_levels_list-2)).astype('int'))

i = 0
for n_levels,base_resolution in zip(n_levels_list,base_resolution_list):
	for n_hidden_layers,n_neurons in zip(n_hidden_layers_list,n_neurons_list):
		task_hyperparameter["network"]['n_neurons'] = n_neurons
		task_hyperparameter["network"]['n_hidden_layers'] = n_hidden_layers
		task_hyperparameter["encoding"]['n_levels'] = float(n_levels)
		task_hyperparameter["encoding"]['base_resolution'] = float(base_resolution)
		file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
		with open(file_path, 'w') as f:
			json.dump(task_hyperparameter, f, ensure_ascii=False)
		i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\GridMLP_share_levels_network
# 78.19379656081493 [77 78 77 78 76]

# %%
# task_folder = os.path.join(main_task_folder, 'GridMLP_share_resolution_12levels')
task_folder = os.path.join(main_task_folder, 'GridMLP_share_resolution_network_1level')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 1,
		"n_features_per_level": 2,
		"log2_hashmap_size": 20,
		"base_resolution": 62,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Tanh",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}


n_neurons_list = [16,32]
n_hidden_layers_list = [0,2]

# base_resolution_list = np.array([16,32,64,128,256],dtype='int')
# base_resolution_list = np.array([7,13, 26, 52,103],dtype='int')
base_resolution_list = np.array([20,40,60,80,120,160,200],dtype='int')


i = 0
for base_resolution in base_resolution_list:
	for n_hidden_layers,n_neurons in zip(n_hidden_layers_list,n_neurons_list):
		task_hyperparameter["network"]['n_neurons'] = n_neurons
		task_hyperparameter["network"]['n_hidden_layers'] = n_hidden_layers
		task_hyperparameter["encoding"]['base_resolution'] = float(base_resolution)
		file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
		with open(file_path, 'w') as f:
			json.dump(task_hyperparameter, f, ensure_ascii=False)
		i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\GridMLP_share_resolution_network_1level

# %%
# task_folder = os.path.join(main_task_folder, 'GridMLP_decoupled_resolution_levels_sin')
task_folder = os.path.join(main_task_folder, 'GridMLP_share_resolution_levels_sin_3e3_3e4')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 12,
		"n_features_per_level": 2,
		"log2_hashmap_size": 20,
		"base_resolution": 62,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Sin",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 300000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}
interior_batch_list = [3000,30000]
per_level_scale_0 = 1.12
n_neurons_list = [16,32]
n_hidden_layers_list = [0,2]

n_levels_list = np.array([1,4,8,16])
max_res_list = np.array([16,32,64,128,256,512])

i = 0
for interior_batch in interior_batch_list:
	for n_levels in n_levels_list:
		base_resolution_list = np.round((max_res_list/(per_level_scale_0**(n_levels-1)))).astype("int")
		print(n_levels,base_resolution_list,(base_resolution_list*per_level_scale_0**(n_levels-1)).astype('int'))
		for base_resolution in base_resolution_list:
			for n_hidden_layers,n_neurons in zip(n_hidden_layers_list,n_neurons_list):
				task_hyperparameter["network"]['n_neurons'] = n_neurons
				task_hyperparameter["network"]['n_hidden_layers'] = n_hidden_layers
				task_hyperparameter["encoding"]['base_resolution'] = float(base_resolution)
				task_hyperparameter["encoding"]["n_levels"] = float(n_levels)
				task_hyperparameter["training"]["interior_batch"] = interior_batch
				file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
				with open(file_path, 'w') as f:
					json.dump(task_hyperparameter, f, ensure_ascii=False)
				i += 1
print(i)
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\GridMLP_share_resolution_levels_sin_3e3_3e4
# 1 [ 16  32  64 128 256 512] [ 16  32  64 128 256 512]
# 4 [ 11  23  46  91 182 364] [ 15  32  64 127 255 511]
# 8 [  7  14  29  58 116 232] [ 15  30  64 128 256 512]
# 16 [ 3  6 12 23 47 94] [ 16  32  65 125 257 514]
# 1 [ 16  32  64 128 256 512] [ 16  32  64 128 256 512]
# 4 [ 11  23  46  91 182 364] [ 15  32  64 127 255 511]
# 8 [  7  14  29  58 116 232] [ 15  30  64 128 256 512]
# 16 [ 3  6 12 23 47 94] [ 16  32  65 125 257 514]
# 96

# %%
task_folder = os.path.join(main_task_folder, 'GridMLP_share_network_sin_resolution')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 8,
		"n_features_per_level": 1,
		"log2_hashmap_size": 30,
		"base_resolution": 8,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Sin",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}

spectral_norm_list = [0,1]
n_neurons_list = [16,32,64,128]
n_hidden_layers_list = [0,1,2,3]

per_level_scale_0 = 1.12
n_levels = 8
max_res_list = np.array([16,32,64,128,256,512])
base_resolution_list = np.round((max_res_list/(per_level_scale_0**(n_levels-1)))).astype("int")
i = 0
for base_resolution in base_resolution_list:
	for spectral_norm in spectral_norm_list:
		for n_neurons in n_neurons_list:
			for n_hidden_layers in n_hidden_layers_list:
				task_hyperparameter["network"]['n_neurons'] = n_neurons
				task_hyperparameter["network"]['n_hidden_layers'] = n_hidden_layers
				task_hyperparameter["network"]['spectral_norm'] = spectral_norm
				task_hyperparameter["encoding"]['base_resolution'] = float(base_resolution)
				file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
				with open(file_path, 'w') as f:
					json.dump(task_hyperparameter, f, ensure_ascii=False)
				i += 1
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\GridMLP_share_network_sin_resolution

# %%
# task_folder = os.path.join(main_task_folder, 'GridMLP_decoupled_resolution_levels_sin')
task_folder = os.path.join(main_task_folder, 'GridMLP_share_resolution_levels_sin_network_3e4')
my_mkdir(task_folder)
print(task_folder)
task_hyperparameter = {
	"encoding": {
		"otype": "Grid",
		"type": "Dense",
		"n_levels": 12,
		"n_features_per_level": 2,
		"log2_hashmap_size": 20,
		"base_resolution": 62,
		"per_level_scale": 1.12,
        "interpolation":"Linear"
	},
	"network": {
		"type": "MLP",
		"activation": "Sin",
		"n_neurons": 32,
		"n_hidden_layers": 1,
		"spectral_norm": 1,
	},
    "loss": {
        "type": "energy",
        "lambda": 1.0,
	},
	"optimizer": {
		"type": "ADAM",
		"learning_rate": 0.005,
		"max_iter": 0,
		"n_step_decay":500,
		"gamma":0.4
    },
	"training":{
		"n_steps": 6000,
		"interior_batch": 30000,
		"boundary_batch": 2000,
		"n_step_output":600,
	},
	"pretrain":{
        "n_steps": 500,
        "n_step_output": 100,
        "n_step_decay": 100,
    },
	"experiment":{
		"n_test": 10,
	}
}

per_level_scale_0 = 1.12
n_neurons_list = [16,32,64]
n_hidden_layers_list = [0,1,2]

n_levels_list = np.array([1,4,8,16])
max_res_list = np.array([16,32,64,128,256])

i = 0
for n_levels in n_levels_list:
	base_resolution_list = np.round((max_res_list/(per_level_scale_0**(n_levels-1)))).astype("int")
	print(n_levels,base_resolution_list,(base_resolution_list*per_level_scale_0**(n_levels-1)).astype('int'))
	for base_resolution in base_resolution_list:
		for n_hidden_layers in n_hidden_layers_list:
			for n_neurons in n_neurons_list:
				if n_hidden_layers == 0 and n_neurons == 16:
					continue
				if n_hidden_layers == 2 and n_neurons == 32:
					continue
				task_hyperparameter["network"]['n_neurons'] = n_neurons
				task_hyperparameter["network"]['n_hidden_layers'] = n_hidden_layers
				task_hyperparameter["encoding"]['base_resolution'] = float(base_resolution)
				task_hyperparameter["encoding"]["n_levels"] = float(n_levels)
				file_path = os.path.join(task_folder, 'config_{}.json'.format(i))
				with open(file_path, 'w') as f:
					json.dump(task_hyperparameter, f, ensure_ascii=False)
				i += 1
print(i)
# Out:
# d:\Research_CAE\MyTinyCUDANN\tiny-cuda-nn\main\microscale_pbc\Tasks\GridMLP_share_resolution_levels_sin_network_3e4
# 1 [ 16  32  64 128 256] [ 16  32  64 128 256]
# 4 [ 11  23  46  91 182] [ 15  32  64 127 255]
# 8 [  7  14  29  58 116] [ 15  30  64 128 256]
# 16 [ 3  6 12 23 47] [ 16  32  65 125 257]
# 140
